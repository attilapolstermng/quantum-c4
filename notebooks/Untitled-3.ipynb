# %%
import os
print(os.getcwd())
print(os.listdir("../"))
# Out:
# /Users/attilapolstermng/Documents/Schule/Maturaarbeit/pygame-quixit/pygame-q-c4/notebooks
# ['requirements.txt', 'quixit_quantum_duel.py', '__pycache__', 'README.md', 'quixit_pygame.py', 'notebooks', 'quixit_main.py']

# %%
# !python3 ../quixit_pygame_Kopie.py
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# qiskit_runtime_service._resolve_cloud_instances:WARNING:2025-10-06 21:03:50,068: Default instance not set. Searching all available instances.
# Traceback (most recent call last):
#   File "/Users/attilapolstermng/Documents/Schule/Maturaarbeit/pygame-quixit/pygame-q-c4/notebooks/../quixit_pygame_Kopie.py", line 389, in <module>
#     main(n_superpos)
#     ~~~~^^^^^^^^^^^^
#   File "/Users/attilapolstermng/Documents/Schule/Maturaarbeit/pygame-quixit/pygame-q-c4/notebooks/../quixit_pygame_Kopie.py", line 215, in main
#     sys.exit()
#     ^^^
# UnboundLocalError: cannot access local variable 'sys' where it is not associated with a value

# %%
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
