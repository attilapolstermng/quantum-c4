# %%
import os
print(os.getcwd())
print(os.listdir("../"))
# Out:
# /Users/attilapolstermng/Documents/Schule/Maturaarbeit/pygame-quixit/pygame-q-c4/notebooks
# ['requirements.txt', 'quixit_quantum_duel.py', '__pycache__', 'README.md', 'quixit_pygame.py', 'notebooks', 'quixit_main.py']

# %%
# !python3 ../qc4.py
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# qiskit_runtime_service._resolve_cloud_instances:WARNING:2025-10-09 18:25:59,938: Default instance not set. Searching all available instances.

# %%
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
